# %%
#!/usr/bin/env python
# coding: utf-8

# In[6]:


import matplotlib.pyplot as plt
import numpy as np


# # line plot

# In[7]:


x = np.array([3,11,16,23,27,34,48,55,56,67])
y = np.array([13,23,34,49,47,61,69,78,84,89])


# In[8]:


plt.plot(x,y)


# In[10]:


plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.plot(x,y)


# In[11]:


plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))

plt.plot(x,y)


# In[15]:


z=np.array([81,73,54,43,32,21,10,6,5,4])
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
plt.plot(x,z)


# In[16]:


z=np.array([81,73,54,43,32,21,10,6,5,4])
plt.plot(x,z)


# In[26]:


z=np.array([81,73,54,43,32,21,10,6,5,4])
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
#marker: o,>,<,v,^,D,*
plt.plot(x,z,marker = 'o',color='pink',ls = ':',
        lw=3,mfc= 'green')


# In[32]:


plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.plot(x,y, label='2022', color='purple')
plt.plot(x,z, label='2022', marker = '<',color='red', ls = ':',
        lw=3,mfc= 'green')


# In[36]:


plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,z)


# In[38]:


z=np.array([81,73,54,43,32,21,10,6,5,4])
plt.figure(figsize=(16,9))
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
plt.plot(x,z)


# In[43]:


z=np.array([81,73,54,43,32,21,10,6,5,4])
plt.figure(figsize=(16,9))
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
#plt.plot(x,y)
plt.scatter(x,y)


# In[53]:


java = np.array([67,45,62,89,45,67,65])
python=np.array([1443,4454,65643,878,6777,88899,53453])
cols=[1,2,1,3,2,1,3]


# In[54]:


plt.title('student group')
plt.xlabel("java")
plt.ylabel("python")
plt.grid()
plt.scatter(java,python, c= cols)


# ### Bar plot

# In[73]:


percentage= [89.00,34.00,45.34,76.45,65.90,11.34]
subjects = [ 'python','php','data structure','java','c','oop']


# In[74]:


plt.title('student group')
plt.xlabel("subjects")
plt.ylabel("percentage")
plt.grid()
plt.bar(subjects,percentage, color = 'orange')


# In[75]:


plt.title('student group')
plt.xlabel("subjects")
plt.ylabel("percentage")
plt.grid()
plt.barh(subjects,percentage, color = 'orange')


# ###PIE CHART

# In[58]:


enrollment = [ 167,67,89,106,48,99]
courses = [ 'python','php','data structure','java','c','oop']


# In[64]:


plt.figure(figsize=(10,10))
plt.pie(enrollment,labels= courses,autopct='%2.2f%%');


# In[65]:


import pandas as pd


# In[66]:


df = pd.read_csv('imcc.csv')


# In[67]:


plt.figure(figsize=(16,9))
plt.barh(df['name'], df['sgpa'])


# In[76]:


plt.figure(figsize=(16,9))
plt.bar(df['name'], df['sgpa'])


# # UNIVARIATE ANALYSIS

# # HISTOGRAM

# In[77]:


marks = np.array([56,67,72,93,75,45,26,58,65,61,68,47])


# In[80]:


plt.xlabel('range of marks')
plt.ylabel('count')
plt.grid()
plt.xticks(range(0,101,10))
plt.hist(marks,color='yellow',bins= range(0,101,10));


# # box plot

# In[81]:


plt.boxplot(marks);


# In[82]:


plt.boxplot(df['sgpa']);


# In[2]:


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# In[3]:


df = pd.read_csv('Salary_Data.csv')


# In[4]:


df.shape


# In[6]:


df.head()


# In[7]:


plt.scatter(df['YearsExperience'],df['Salary'])


# In[8]:


a = np.arange(1,10,0.25)
a


# In[11]:


b = a*1.56+32.07
b


# In[12]:


plt.plot(a,b)


# In[13]:


x = df['YearsExperience'].values
y= df['Salary']
x


# In[14]:


y


# In[15]:


x = x.reshape(30,1)


# In[16]:


x


# # import the class

# In[17]:


from sklearn.linear_model import LinearRegression


# # creat the object of linear regression

# In[18]:


regressor = LinearRegression()


# # train the algorithms with data

# In[19]:


regressor.fit(x,y)


# # predict on unseen data

# In[20]:


regressor.predict([[15]])


# In[21]:


regressor.predict([[20]])


# In[ ]:





# In[ ]:

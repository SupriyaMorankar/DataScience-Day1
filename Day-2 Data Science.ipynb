# %%
import pandas as pd

# %%
import numpy as np

# %%
x = np.array([1,3,3,4,5,6,7,8])

# %%
np.mean(x)
# Out:
# 4.625

# %%
np.median(x)
# Out:
# 4.5

# %% [markdown]
# ## mean absolute deviation

# %%
np.mean(abs(x-x.mean()))
# Out:
# 1.875

# %%
x = np.ones(10)+20

# %%
x
# Out:
# array([21., 21., 21., 21., 21., 21., 21., 21., 21., 21.])

# %%
np.mean(abs(x-x.mean()))
# Out:
# 0.0

# %% [markdown]
# ## varience

# %%
num = np.array([1,3,3,4,5,6,7,8,12,23])
np.mean((num - num.mean())**2)
# Out:
# 36.36

# %% [markdown]
# ## standard deviation

# %%
np.sqrt(np.mean((num - num.mean())**2))
# square root of varience is standard deviation
# Out:
# 6.029925372672534

# %%
num.std()
# Out:
# 6.029925372672534

# %%
np.std(num)
# Out:
# 6.029925372672534

# %% [markdown]
# ## structured Data Analysis

# %%
# dataset is the collection of data that is treated as a single unit by a computer
# datase contains a lot of separate pieces of data but can be used to train an algorithm with the goal of 
# finding predictable patterns inside the whole dataset 

import os
os.getcwd()
# Out:
# 'C:\\Users\\Expert'

# %% [markdown]
# ## import the dataset

# %%
df = pd.read_csv('imcc.csv')

# %%
df
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   age  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha  23.0
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale  25.0
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   NaN
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   NaN
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar  21.0
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki  20.0
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar  23.0
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   NaN
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar  22.0
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni  22.0
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge  21.0
# ...

# %%
df.shape
# Out:
# (51, 11)

# %%
list(df.columns)
# Out:
# ['टाइमस्टँप',
#  'roll_num',
#  'name',
#  'middlename',
#  'surname',
#  'age',
#  'sgpa',
#  'gender',
#  'favorite_sport',
#  'native_city',
#  'year_of_passing_10th']

# %%
df.dtypes
# Out:
# टाइमस्टँप                object
# roll_num                  int64
# name                     object
# middlename               object
# surname                  object
# age                     float64
# sgpa                    float64
# gender                   object
# favorite_sport           object
# native_city              object
# year_of_passing_10th      int64
# dtype: object

# %%
df.head()
# Out:
#              टाइमस्टँप  roll_num       name middlename   surname   age  sgpa  \
# 0  30/05/2023 14:26:35   2201184    Shubham     Kumar      Sinha  23.0  8.29
# 1  30/05/2023 14:26:56   2201129     Pranav   Prashant    Modale  25.0  7.80
# 2  30/05/2023 14:27:27   2201125    Pratik     Sharad   Masalkar   NaN  8.31
# 3  30/05/2023 14:27:43   2201154     Ranvir    Gajanan     Pawar   NaN  8.00
# 4  30/05/2023 14:27:48   2201193  Siddhesh      Suresh   Uttekar  21.0  8.40
#
#   gender      favorite_sport native_city  year_of_passing_10th
# 0   Male  Cricket , Football       Patna                  2014
# 1   Male             Cricket        Pune                  2014
# 2   Male           Badminton        Pune                  2017
# 3   Male               chess     buldana                  2014
# 4   Male             cricket        Pune                  2016

# %%
df.tail()
# Out:
#               टाइमस्टँप  roll_num       name  middlename   surname   age  \
# 46  30/05/2023 14:30:39   2201157     Nikhil       Ashok     Rande   NaN
# 47  30/05/2023 14:31:04   2201118  ‎ Shubham    ‎ Sanjay    ‎ Mali  21.0
# 48  30/05/2023 14:31:14   2201194  shraddha   jaiprakash     varma  22.0
# 49  30/05/2023 14:31:18   2201106     Priya       Pradip  Kulkarni  22.0
# 50  30/05/2023 14:31:47   2201107    Swapnil       Suhas  Kulkarni  22.0
#
#     sgpa  gender favorite_sport native_city  year_of_passing_10th
# 46  7.00    Male        Kabaddi        Akot                  2016
# 47  9.15    Male      ‎ Cricket      ‎ Pune                  2017
# 48  7.89  Female      badminton        wani                  2017
# 49  8.00  Female      Badminton        Pune                  2017
# 50  7.28    Male        Cricket        Pune                  2016

# %% [markdown]
# ## slicing

# %%
df.iloc[2:9,3:8]
# Out:
#   middlename   surname   age  sgpa gender
# 2    Sharad   Masalkar   NaN  8.31   Male
# 3    Gajanan     Pawar   NaN  8.00   Male
# 4     Suresh   Uttekar  21.0  8.40   Male
# 5    Shirish  Lumpatki  20.0  8.71   Male
# 6      Kumar     Kumar  23.0  7.50   Male
# 7  Sambhaji    Markile   NaN  7.79   Male
# 8    subhash   patidar  22.0  8.00   Male

# %%
df.iloc[:9,3:8]
# Out:
#   middlename   surname   age  sgpa gender
# 0     Kumar      Sinha  23.0  8.29   Male
# 1   Prashant    Modale  25.0  7.80   Male
# 2    Sharad   Masalkar   NaN  8.31   Male
# 3    Gajanan     Pawar   NaN  8.00   Male
# 4     Suresh   Uttekar  21.0  8.40   Male
# 5    Shirish  Lumpatki  20.0  8.71   Male
# 6      Kumar     Kumar  23.0  7.50   Male
# 7  Sambhaji    Markile   NaN  7.79   Male
# 8    subhash   patidar  22.0  8.00   Male

# %%
df.iloc[:9,:8]
# Out:
#              टाइमस्टँप  roll_num       name middlename   surname   age  sgpa  \
# 0  30/05/2023 14:26:35   2201184    Shubham     Kumar      Sinha  23.0  8.29
# 1  30/05/2023 14:26:56   2201129     Pranav   Prashant    Modale  25.0  7.80
# 2  30/05/2023 14:27:27   2201125    Pratik     Sharad   Masalkar   NaN  8.31
# 3  30/05/2023 14:27:43   2201154     Ranvir    Gajanan     Pawar   NaN  8.00
# 4  30/05/2023 14:27:48   2201193  Siddhesh      Suresh   Uttekar  21.0  8.40
# 5  30/05/2023 14:28:03   2201115     Sairaj    Shirish  Lumpatki  20.0  8.71
# 6  30/05/2023 14:28:03   2201110     Rahul       Kumar     Kumar  23.0  7.50
# 7  30/05/2023 14:28:06   2201124     Akash   Sambhaji    Markile   NaN  7.79
# 8  30/05/2023 14:28:07   2201145     harsh     subhash   patidar  22.0  8.00
#
#   gender
# 0   Male
# 1   Male
# 2   Male
# 3   Male
# 4   Male
# 5   Male
# 6   Male
# 7   Male
# 8   Male

# %%
df.iloc[9,8]
# Out:
# 'Sachin Tendulkar'

# %%
df.iloc[1,8]
# Out:
# 'Cricket'

# %%
df.iloc[2:9,2] #slice multiple row and one column
# Out:
# 2      Pratik
# 3       Ranvir
# 4    Siddhesh
# 5       Sairaj
# 6       Rahul
# 7       Akash
# 8       harsh
# Name: name, dtype: object

# %%
df.iloc[5,:] # slice one row and column
# Out:
# टाइमस्टँप               30/05/2023 14:28:03
# roll_num                            2201115
# name                                 Sairaj
# middlename                          Shirish
# surname                            Lumpatki
# age                                    20.0
# sgpa                                   8.71
# gender                                 Male
# favorite_sport                   volleyball
# native_city                      Ahmednagar
# year_of_passing_10th                   2017
# Name: 5, dtype: object

# %%
df.iloc[[2,4,5,6,6],3:8] #only slice particular row and column
# Out:
#   middlename   surname   age  sgpa gender
# 2    Sharad   Masalkar   NaN  8.31   Male
# 4     Suresh   Uttekar  21.0  8.40   Male
# 5    Shirish  Lumpatki  20.0  8.71   Male
# 6      Kumar     Kumar  23.0  7.50   Male
# 6      Kumar     Kumar  23.0  7.50   Male

# %%
df.loc[:,'name'] #slice using column name
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        harsh
# 9         Omkar
# 10      Prajwal
# 11       tejas
# 12      Vaibhav
# 13      Gaurav
# 14      sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      muskan
# 20    Ashutosh
# 21        VIVEK
# 22    Sharvari
# 23       Leena
# 24      vedika
# 25     Atharva
# 26    himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       sakshi
# 42       Jyoti
# 43      NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df.loc[: , ['name','gender','sgpa']]
# Out:
#          name  gender   sgpa
# 0     Shubham    Male   8.29
# 1      Pranav    Male   7.80
# 2     Pratik     Male   8.31
# 3      Ranvir    Male   8.00
# 4   Siddhesh     Male   8.40
# 5      Sairaj    Male   8.71
# 6      Rahul     Male   7.50
# 7      Akash     Male   7.79
# 8      harsh     Male   8.00
# 9       Omkar    Male   9.81
# 10    Prajwal    Male   7.90
# 11     tejas     Male   7.85
# 12    Vaibhav    Male   7.00
# 13    Gaurav     Male   8.90
# 14    sindura  Female   8.10
# 15    Hitesh     Male   8.25
# 16    Janhavi  Female   8.75
# 17       Raj     Male   7.71
# 18     Manish    Male   8.46
# 19    muskan   Female   8.05
# 20  Ashutosh     Male   7.54
# 21      VIVEK    Male   7.60
# 22  Sharvari   Female   7.82
# 23     Leena   Female   7.89
# 24    vedika   Female   8.89
# 25   Atharva     Male   7.64
# 26  himanshi   Female   8.80
# 27   Harshita  Female   8.61
# 28      Aditi  Female   8.00
# 29    Akshata  Female  75.00
# 30    Mahima   Female   7.68
# ...

# %%
df['name']
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        harsh
# 9         Omkar
# 10      Prajwal
# 11       tejas
# 12      Vaibhav
# 13      Gaurav
# 14      sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      muskan
# 20    Ashutosh
# 21        VIVEK
# 22    Sharvari
# 23       Leena
# 24      vedika
# 25     Atharva
# 26    himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       sakshi
# 42       Jyoti
# 43      NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df[['name','surname']]
# Out:
#          name     surname
# 0     Shubham       Sinha
# 1      Pranav      Modale
# 2     Pratik     Masalkar
# 3      Ranvir       Pawar
# 4   Siddhesh      Uttekar
# 5      Sairaj    Lumpatki
# 6      Rahul        Kumar
# 7      Akash      Markile
# 8      harsh      patidar
# 9       Omkar    Kulkarni
# 10    Prajwal     Shendge
# 11     tejas         mane
# 12    Vaibhav        Raut
# 13    Gaurav       Shimpi
# 14    sindura     rathore
# 15    Hitesh    Mohadikar
# 16    Janhavi  Sangaonkar
# 17       Raj        Verma
# 18     Manish        Teke
# 19    muskan       shipai
# 20  Ashutosh       Saoji
# 21      VIVEK        MORE
# 22  Sharvari       Shinde
# 23     Leena       Thorat
# 24    vedika     kandekar
# 25   Atharva     Paradkar
# 26  himanshi         vyas
# 27   Harshita      Maurya
# 28      Aditi       Patil
# 29    Akshata      thakre
# 30    Mahima          Pal
# 31  Aishwarya    Lokhande
# 32    Manali       Petare
# 33    Ankita       Madane
# ...

# %%
df.name
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        harsh
# 9         Omkar
# 10      Prajwal
# 11       tejas
# 12      Vaibhav
# 13      Gaurav
# 14      sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      muskan
# 20    Ashutosh
# 21        VIVEK
# 22    Sharvari
# 23       Leena
# 24      vedika
# 25     Atharva
# 26    himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       sakshi
# 42       Jyoti
# 43      NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df.drop(4) #display all the rows expect row number 4
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   age  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha  23.0
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale  25.0
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   NaN
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   NaN
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki  20.0
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar  23.0
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   NaN
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar  22.0
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni  22.0
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge  21.0
# 11  30/05/2023 14:28:10   2201121     tejas    Uttareshwar        mane   NaN
# ...

# %%
df.drop([1,2,3,4,5,6])
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   age  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha  23.0
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   NaN
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar  22.0
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni  22.0
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge  21.0
# 11  30/05/2023 14:28:10   2201121     tejas    Uttareshwar        mane   NaN
# 12  30/05/2023 14:28:11   2201159    Vaibhav        Kailas        Raut   NaN
# 13  30/05/2023 14:28:13   2201173    Gaurav          Mohan      Shimpi  22.0
# 14  30/05/2023 14:28:15   2201182    sindura         singh     rathore  23.0
# 15  30/05/2023 14:28:15   2201130    Hitesh    Dnyaneshwar   Mohadikar  22.0
# 16  30/05/2023 14:28:16   2201163    Janhavi          Ajit  Sangaonkar   NaN
# ...

# %%
df
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   age  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha  23.0
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale  25.0
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   NaN
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   NaN
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar  21.0
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki  20.0
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar  23.0
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   NaN
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar  22.0
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni  22.0
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge  21.0
# ...

# %%
df.drop("age" , axis=1 , inplace=True)

# %%
df
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   sgpa  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha   8.29
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale   7.80
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   8.31
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   8.00
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar   8.40
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki   8.71
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar   7.50
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   7.79
# 8   30/05/2023 14:28:07   2201145     harsh        subhash     patidar   8.00
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni   9.81
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge   7.90
# ...

# %% [markdown]
# ## summary

# %%
df.describe()
# Out:
#            roll_num       sgpa  year_of_passing_10th
# count  5.100000e+01  51.000000             51.000000
# mean   2.118559e+06   9.383333           2016.352941
# std    3.889351e+05   9.396436              1.110379
# min    2.201260e+05   7.000000           2012.000000
# 25%    2.201118e+06   7.620000           2016.000000
# 50%    2.201146e+06   7.960000           2017.000000
# 75%    2.201174e+06   8.430000           2017.000000
# max    2.201206e+06  75.000000           2018.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   टाइमस्टँप             51 non-null     object
#  1   roll_num              51 non-null     int64
#  2   name                  51 non-null     object
#  3   middlename            51 non-null     object
#  4   surname               51 non-null     object
#  5   sgpa                  51 non-null     float64
#  6   gender                51 non-null     object
#  7   favorite_sport        51 non-null     object
#  8   native_city           51 non-null     object
#  9   year_of_passing_10th  51 non-null     int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 4.1+ KB

# %%
df.count()
# Out:
# टाइमस्टँप               51
# roll_num                51
# name                    51
# middlename              51
# surname                 51
# sgpa                    51
# gender                  51
# favorite_sport          51
# native_city             51
# year_of_passing_10th    51
# dtype: int64

# %%
df.mean()
# Out:
# C:\Users\Expert\AppData\Local\Temp\ipykernel_13536\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# roll_num                2.118559e+06
# sgpa                    9.383333e+00
# year_of_passing_10th    2.016353e+03
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Expert\AppData\Local\Temp\ipykernel_13536\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# roll_num                2201146.00
# sgpa                          7.96
# year_of_passing_10th       2017.00
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\Expert\AppData\Local\Temp\ipykernel_13536\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# roll_num                388935.108564
# sgpa                         9.396436
# year_of_passing_10th         1.110379
# dtype: float64

# %%
df['sgpa'].mean() #applying properties to the individual column
# Out:
# 9.383333333333333

# %%
df['sgpa'].max()
# Out:
# 75.0

# %%
df['sgpa'].min()
# Out:
# 7.0

# %%
df['sgpa'].sum()
# Out:
# 478.54999999999995

# %%
df['name'].str.upper()#convert all to upppercase
# Out:
# 0       SHUBHAM
# 1        PRANAV
# 2       PRATIK
# 3        RANVIR
# 4     SIDDHESH
# 5        SAIRAJ
# 6        RAHUL
# 7        AKASH
# 8        HARSH
# 9         OMKAR
# 10      PRAJWAL
# 11       TEJAS
# 12      VAIBHAV
# 13      GAURAV
# 14      SINDURA
# 15      HITESH
# 16      JANHAVI
# 17         RAJ
# 18       MANISH
# 19      MUSKAN
# 20    ASHUTOSH
# 21        VIVEK
# 22    SHARVARI
# 23       LEENA
# 24      VEDIKA
# 25     ATHARVA
# 26    HIMANSHI
# 27     HARSHITA
# 28        ADITI
# 29      AKSHATA
# 30      MAHIMA
# 31    AISHWARYA
# 32      MANALI
# 33      ANKITA
# 34         YASH
# 35     APEKSHA
# 36     SAURABH
# 37      KSHITIJ
# 38     SANDESH
# 39        SUYOG
# 40      PRERNA
# 41       SAKSHI
# 42       JYOTI
# 43      NILESH
# 44       PRANAV
# 45          RAJ
# 46       NIKHIL
# 47    ‎ SHUBHAM
# 48    SHRADDHA
# 49       PRIYA
# 50      SWAPNIL
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       shubham
# 1        pranav
# 2       pratik
# 3        ranvir
# 4     siddhesh
# 5        sairaj
# 6        rahul
# 7        akash
# 8        harsh
# 9         omkar
# 10      prajwal
# 11       tejas
# 12      vaibhav
# 13      gaurav
# 14      sindura
# 15      hitesh
# 16      janhavi
# 17         raj
# 18       manish
# 19      muskan
# 20    ashutosh
# 21        vivek
# 22    sharvari
# 23       leena
# 24      vedika
# 25     atharva
# 26    himanshi
# 27     harshita
# 28        aditi
# 29      akshata
# 30      mahima
# 31    aishwarya
# 32      manali
# 33      ankita
# 34         yash
# 35     apeksha
# 36     saurabh
# 37      kshitij
# 38     sandesh
# 39        suyog
# 40      prerna
# 41       sakshi
# 42       jyoti
# 43      nilesh
# 44       pranav
# 45          raj
# 46       nikhil
# 47    ‎ shubham
# 48    shraddha
# 49       priya
# 50      swapnil
# Name: name, dtype: object

# %%
df['name'].str.title()
# Out:
# 0       Shubham
# 1        Pranav
# 2       Pratik
# 3        Ranvir
# 4     Siddhesh
# 5        Sairaj
# 6        Rahul
# 7        Akash
# 8        Harsh
# 9         Omkar
# 10      Prajwal
# 11       Tejas
# 12      Vaibhav
# 13      Gaurav
# 14      Sindura
# 15      Hitesh
# 16      Janhavi
# 17         Raj
# 18       Manish
# 19      Muskan
# 20    Ashutosh
# 21        Vivek
# 22    Sharvari
# 23       Leena
# 24      Vedika
# 25     Atharva
# 26    Himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30      Mahima
# 31    Aishwarya
# 32      Manali
# 33      Ankita
# 34         Yash
# 35     Apeksha
# 36     Saurabh
# 37      Kshitij
# 38     Sandesh
# 39        Suyog
# 40      Prerna
# 41       Sakshi
# 42       Jyoti
# 43      Nilesh
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48    Shraddha
# 49       Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df['name'].str.strip()
# Out:
# 0       Shubham
# 1        Pranav
# 2        Pratik
# 3        Ranvir
# 4      Siddhesh
# 5        Sairaj
# 6         Rahul
# 7         Akash
# 8         harsh
# 9         Omkar
# 10      Prajwal
# 11        tejas
# 12      Vaibhav
# 13       Gaurav
# 14      sindura
# 15       Hitesh
# 16      Janhavi
# 17          Raj
# 18       Manish
# 19       muskan
# 20     Ashutosh
# 21        VIVEK
# 22     Sharvari
# 23        Leena
# 24       vedika
# 25      Atharva
# 26     himanshi
# 27     Harshita
# 28        Aditi
# 29      Akshata
# 30       Mahima
# 31    Aishwarya
# 32       Manali
# 33       Ankita
# 34         Yash
# 35      Apeksha
# 36      Saurabh
# 37      Kshitij
# 38      Sandesh
# 39        Suyog
# 40       Prerna
# 41       sakshi
# 42        Jyoti
# 43       NILESH
# 44       Pranav
# 45          Raj
# 46       Nikhil
# 47    ‎ Shubham
# 48     shraddha
# 49        Priya
# 50      Swapnil
# Name: name, dtype: object

# %%
df['name']=df['name'].str.title()
df['middlename']=df['middlename'].str.title()
df['surname']=df['surname'].str.title()

# %%
df
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   sgpa  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha   8.29
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale   7.80
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   8.31
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   8.00
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar   8.40
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki   8.71
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar   7.50
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   7.79
# 8   30/05/2023 14:28:07   2201145     Harsh        Subhash     Patidar   8.00
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni   9.81
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge   7.90
# ...

# %%
df['favorite_sport']=df['favorite_sport'].str.title()
df['name']=df['name'].str.title()

# %%
df
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   sgpa  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha   8.29
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale   7.80
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   8.31
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   8.00
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar   8.40
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki   8.71
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar   7.50
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   7.79
# 8   30/05/2023 14:28:07   2201145     Harsh        Subhash     Patidar   8.00
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni   9.81
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge   7.90
# ...

# %%
df.isnull() #is any value is null then it show true
# Out:
#     टाइमस्टँप  roll_num   name  middlename  surname   sgpa  gender  \
# 0       False     False  False       False    False  False   False
# 1       False     False  False       False    False  False   False
# 2       False     False  False       False    False  False   False
# 3       False     False  False       False    False  False   False
# 4       False     False  False       False    False  False   False
# 5       False     False  False       False    False  False   False
# 6       False     False  False       False    False  False   False
# 7       False     False  False       False    False  False   False
# 8       False     False  False       False    False  False   False
# 9       False     False  False       False    False  False   False
# 10      False     False  False       False    False  False   False
# 11      False     False  False       False    False  False   False
# 12      False     False  False       False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# टाइमस्टँप               0
# roll_num                0
# name                    0
# middlename              0
# surname                 0
# sgpa                    0
# gender                  0
# favorite_sport          0
# native_city             0
# year_of_passing_10th    0
# dtype: int64

# %%
# if there is any true value then it is represented by true and sum of all isnull represented the number of null values 
# so in the place of null value we usually place median of the data

df['sgpa']=df['sgpa'].fillna(df['sgpa'].median())

# %%
df
# Out:
#               टाइमस्टँप  roll_num       name    middlename     surname   sgpa  \
# 0   30/05/2023 14:26:35   2201184    Shubham        Kumar        Sinha   8.29
# 1   30/05/2023 14:26:56   2201129     Pranav      Prashant      Modale   7.80
# 2   30/05/2023 14:27:27   2201125    Pratik        Sharad     Masalkar   8.31
# 3   30/05/2023 14:27:43   2201154     Ranvir       Gajanan       Pawar   8.00
# 4   30/05/2023 14:27:48   2201193  Siddhesh         Suresh     Uttekar   8.40
# 5   30/05/2023 14:28:03   2201115     Sairaj       Shirish    Lumpatki   8.71
# 6   30/05/2023 14:28:03   2201110     Rahul          Kumar       Kumar   7.50
# 7   30/05/2023 14:28:06   2201124     Akash      Sambhaji      Markile   7.79
# 8   30/05/2023 14:28:07   2201145     Harsh        Subhash     Patidar   8.00
# 9   30/05/2023 14:28:08   2201105      Omkar        Milind    Kulkarni   9.81
# 10  30/05/2023 14:28:10   2201171    Prajwal        Pramod     Shendge   7.90
# ...

# %% [markdown]
# ## boolean filtering

# %%
df['sgpa']>8.9
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29     True
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42    False
# 43    False
# 44    False
# 45     True
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# Name: sgpa, dtype: bool

# %%
df[df['sgpa']>8.9]
# Out:
#               टाइमस्टँप  roll_num       name middlename   surname   sgpa  \
# 9   30/05/2023 14:28:08   2201105      Omkar     Milind  Kulkarni   9.81
# 29  30/05/2023 14:29:04   2201188    Akshata      Vijay    Thakre  75.00
# 31  30/05/2023 14:29:06   2201113  Aishwarya     Prasad  Lokhande   9.10
# 41  30/05/2023 14:30:15    220143     Sakshi    Santosh   Patidar  10.00
# 45  30/05/2023 14:30:32   2201167        Raj   Rajendra     Kumar   9.60
# 47  30/05/2023 14:31:04   2201118  ‎ Shubham   ‎ Sanjay    ‎ Mali   9.15
#
#     gender    favorite_sport native_city  year_of_passing_10th
# 9     Male  Sachin Tendulkar        Pune                  2018
# 29  Female           Cricket        pune                  2017
# 31  Female         Badminton        pune                  2017
# 41  Female           Cricket        durg                  2015
# 45    Male           Cricket        pune                  2016
# 47    Male         ‎ Cricket      ‎ Pune                  2017

# %%
df.loc[29,'sgpa']=7.5

# %%
df['sgpa'].min(),df['sgpa'].max()
# Out:
# (7.0, 10.0)

# %%
df['favorite_sport'].mode()
# Out:
# 0    Cricket
# Name: favorite_sport, dtype: object

# %%
df['favorite_sport'].value_counts()
# Out:
# Cricket               24
# Badminton             10
# Football               4
# Volleyball             2
# Table Tennis           2
# Cricket , Football     1
# Chess                  1
# Sachin Tendulkar       1
# -                      1
# Vollyball              1
# Basketball             1
# Carrom                 1
# Kabaddi                1
# ‎ Cricket              1
# Name: favorite_sport, dtype: int64

# %%
df[(df['gender']=='Female') & (df['favorite_sport']=='Cricket')]
# Out:
#               टाइमस्टँप  roll_num       name middlename  surname   sgpa  \
# 14  30/05/2023 14:28:15   2201182    Sindura      Singh  Rathore   8.10
# 19  30/05/2023 14:28:26   1951022    Muskan     Shabbir   Shipai   8.05
# 22  30/05/2023 14:28:32   2201175  Sharvari       Sunil   Shinde   7.82
# 26  30/05/2023 14:28:48   2201196  Himanshi                 Vyas   8.80
# 29  30/05/2023 14:29:04   2201188    Akshata      Vijay   Thakre   7.50
# 33  30/05/2023 14:29:16   2201116    Ankita      Tanaji   Madane   7.00
# 41  30/05/2023 14:30:15    220143     Sakshi    Santosh  Patidar  10.00
# 42  30/05/2023 14:30:17   2201205     Jyoti           .    Yadav   8.14
#
#     gender favorite_sport  native_city  year_of_passing_10th
# 14  Female        Cricket  muzzafarpur                  2017
# 19  Female        Cricket         pune                  2017
# 22  Female        Cricket        karad                  2016
# 26  Female        Cricket       indore                  2017
# ...

# %%
df[df['year_of_passing_10th']==2015]['name'].count()
# Out:
# 4

# %%
x = df[(df['gender']=='Female') & (df['favorite_sport']=='Cricket')]

# %%
x.to_csv('output.csv',index=False)#save the output in csv file
